# %%
## importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("diabetes1.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
d=data[['Pregnancies','Outcome']]
d
# Out:
#      Pregnancies  Outcome
# 0              6        1
# 1              1        0
# 2              8        1
# 3              1        0
# 4              0        1
# ..           ...      ...
# 763           10        0
# 764            2        0
# 765            5        0
# 766            1        1
# 767            1        0
#
# [768 rows x 2 columns]

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ***Insights***

# %% [markdown]
# 1. There are total 768 rows and 9 columns and every column has total 768 values so there
# are no null values.
# 2. Women having maximum age is 81. and Minimum age is 21 and Average is 33.
# 3. There are 81 womens having age more than 50 yrs.
# 4. Average BMI is 31.
# 5. 394 Women takes Insulin while 374 womens didn't take insulin.
# 6. Average blood pressure is 69
# 7. Average thickness of women is 20
# 8. if bloodpresure is more than 120(max) they having dibites.
# 9. Pregnancies count is more than 6 there will posible to detect dibites.
# 10. 10.if Glucose is more than 140 there is predibites,and there is max(199) it should present dibites.
# 11. age is greater than 41 they have dibites.

# %%
data.describe(include="O")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data.describe(include="O")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
data.head()

# %%
data.Pregnancies.value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.replace(0,np.NaN)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      NaN  33.6
# 1            1.0     85.0           66.0           29.0      NaN  26.6
# 2            8.0    183.0           64.0            NaN      NaN  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      NaN  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN      NaN  30.1
# 767          1.0     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
data.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
np.mean(data)
# Out:
# 40.02614308449074

# %%
np.median(data)
# Out:
# 24.3

# %%
from scipy import stats

# %%
stats.mode(data)
# Out:
# ModeResult(mode=array([ 1.   , 99.   , 70.   ,  0.   ,  0.   , 32.   ,  0.254, 22.   ,
#         0.   ]), count=array([135.,  17.,  57., 227., 374.,  13.,   6.,  72., 500.]))

# %%
IQR=stats.iqr(data)

# %%
IQR
# Out:
# 60.53775

# %%
q1 = np.percentile(data,25)
q1
# Out:
# 0.46225000000000005

# %%
q3=np.percentile(data,75)
q3
# Out:
# 61.0

# %%
print("Q1 = ",q1)
print("Q3 = ",q3)
print("IQR = ",q3-q1)
# Out:
# Q1 =  0.46225000000000005
# Q3 =  61.0
# IQR =  60.53775

# %%
min=q1-1.5(IQR)
# Out:
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# C:\Users\Saurav Mahale\AppData\Local\Temp\ipykernel_42224\2705213826.py:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   min=q1-1.5(IQR)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 min=q1-1.5(IQR)
#
# TypeError: 'float' object is not callable

# %%
## variance and standard deviation
np.var(data)
# Out:
# C:\Users\Saurav Mahale\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Pregnancies                    11.339272
# Glucose                      1020.917262
# BloodPressure                 374.159449
# SkinThickness                 254.141900
# Insulin                     13263.886875
# BMI                            62.079046
# DiabetesPedigreeFunction        0.109636
# Age                           138.122964
# Outcome                         0.227186
# dtype: float64

# %%
np.std(data)
# Out:
# C:\Users\Saurav Mahale\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Pregnancies                   3.367384
# Glucose                      31.951796
# BloodPressure                19.343202
# SkinThickness                15.941829
# Insulin                     115.168949
# BMI                           7.879026
# DiabetesPedigreeFunction      0.331113
# Age                          11.752573
# Outcome                       0.476641
# dtype: float64

# %%
cnt=data.iloc[(data['Age']<60) & (data['Age'>20])]
cnt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 cnt=data.iloc[(data['Age']<60) & (data['Age'>20])]
#       2 cnt
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
cnt.Age.value_counts().sum()
# Out:
# 32

# %%
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 763    False
# 764     True
# 765     True
# 766     True
# 767     True
# Name: Age, Length: 768, dtype: bool

# %%
plt.pie()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 plt.pie(y="columns")
#
# TypeError: pie() got an unexpected keyword argument 'y'

# %%
pd.DataFrame(data).plot(kind='hist')
plt.show()

# %%
df.Age.unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %%
#df.Age.value_counts()

# %%
sns.lineplot(x="Pregnancies",y="BloodPressure",data=data,errorbar=None,hue="Outcome")
plt.show()

# %% [markdown]
# ***insites***

# %% [markdown]
# 1.pregnancies range in between 7.5 to 10.0 and bloodpresure is above 80.0 they have dibites.
# 2.pregnancies range in between 3 to 6.0 and bloodpresure is increase in between 77.5 to 80.0 they have dibites.
# 3.pregnancies range in between 10.0 to 13.0 and bloodpresure is increase in between 65 to 72.5 they have dibites.

# %%
sns.lineplot(x="Age",y="BloodPressure",data=df,errorbar=None,hue="Outcome")
plt.show()

# %%
sns.boxplot(x="Age",y="BloodPressure",data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[289], line 1
# ----> 1 sns.boxplot(x="Age",y="BloodPressure",data=data)
#       2 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
# ...

# %%
#sns.scatterplot(x="Pregnancies",y="BloodPressure",data=df,hue="Outcome")
#plt.show()

# %%
sns.barplot(x="Age",y="BloodPressure",data=data,errorbar=None,hue="Outcome")
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.barplot(x="Age",y="SkinThickness",data=data,errorbar=None,hue="Outcome")
plt.show()

# %%
sns.barplot(x="Insulin",y="BloodPressure",data=df,errorbar=None,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.barplot(x="Insulin",y="BloodPressure",data=df,errorbar=None,)
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.barplot(x="Pregnancies",y="BMI",data=df,errorbar=None,)
plt.show()

# %%
sns.scatterplot(x="DiabetesPedigreeFunction",y="Glucose",data=df,hue="Outcome")
plt.show()

# %%
sns.lineplot(x="Age",y="DiabetesPedigreeFunction",data=df,hue="Outcome",errorbar=None)
plt.show()

# %%
sns.scatterplot(x="Pregnancies",y="Age",data=df,)
plt.show()

# %%
sns.pairplot(data=data, hue='Outcome')
plt.show()

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.Age.value_counts()
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 50     8
# 51     8
# 52     8
# 44     8
# 58     7
# 47     6
# 54     6
# 49     5
# 48     5
# 57     5
# 53     5
# 60     5
# 66     4
# 63     4
# 62     4
# 55     4
# 67     3
# 56     3
# 59     3
# 65     3
# 69     2
# 61     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64

# %%
sns.boxplot(x="Glucose",data=data,)
plt.show()

# %%
data.loc[data['Glucose']==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.scatterplot(x="Glucose",y="BloodPressure",data=data,)
plt.show()

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.histplot(x="Pregnancies",data=data)
plt.show()

# %%
sns.barplot(x="Pregnancies",y="Age",data=data)
plt.show()

# %%
sns.barplot(x="Glucose",y="Age",data=data)
plt.show()

# %%
sns.histplot(x="Glucose",data=data ,hue="Outcome",kde=True)
plt.show()

# %%
sns.histplot(x="Age",data=data ,hue="Outcome",kde=True,)
plt.show()
